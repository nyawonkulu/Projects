# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import sys 
sys.path.append('/content/drive/Project')

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/open?id=1z3ll5ukEg44KbKhqmq48ix2F-KJPN3u4'
fluff, id = link.split('=')
model = drive.CreateFile({'id':id}) 
model.GetContentFile('Main.py')  

link = 'https://drive.google.com/open?id=1sENRc5DQEyLRW15JNfRJtP8TuhohVl2u'
fluff, id = link.split('=')
load = drive.CreateFile({'id':id}) 
load.GetContentFile('Dataset_loader.py')  

link = 'https://drive.google.com/open?id=1oYnorvsZ1J53u-nygvI7vdY2mo27iX0L'
fluff, id = link.split('=')
dataset = drive.CreateFile({'id':id}) 
dataset.GetContentFile('file_out.pkl.gz') 

link = 'https://drive.google.com/open?id=1kTXZN8IM5W3Nt4BuU775u7g5teFXm5_G'
fluff, id = link.split('=')
dataset = drive.CreateFile({'id':id}) 
dataset.GetContentFile('Model.py')  

link = 'https://drive.google.com/open?id=1AFSDMAaQclJvljdxwJrvRkc2CqHpUZ_c'
fluff, id = link.split('=')
dataset = drive.CreateFile({'id':id}) 
dataset.GetContentFile('Augmentation.py')  

link = 'https://drive.google.com/open?id=1xMPb_hf56WnFzzpldxFszGKjsTvBDqsD'
fluff, id = link.split('=')
dataset = drive.CreateFile({'id':id}) 
dataset.GetContentFile('Training.py')

# %%
import Main
Main.main()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 120, 120, 1)]     0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 120, 120, 32)      288
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 120, 120, 32)      128
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 60, 60, 32)        0
# _________________________________________________________________
# activation_16 (Activation)   (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 60, 60, 64)        18432
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 60, 60, 64)        256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# activation_17 (Activation)   (None, 30, 30, 64)        0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 128)       73728
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# activation_18 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 256)       294912
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 256)         0
# _________________________________________________________________
# activation_19 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_transpose_10 (Conv2DT (None, 8, 8, 256)         589824
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# activation_20 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_11 (Conv2DT (None, 16, 16, 128)       294912
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# cropping2d_2 (Cropping2D)    (None, 30, 30, 128)       0
# _________________________________________________________________
# activation_21 (Activation)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_transpose_12 (Conv2DT (None, 30, 30, 64)        73728
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 30, 30, 64)        256
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 60, 60, 64)        0
# _________________________________________________________________
# activation_22 (Activation)   (None, 60, 60, 64)        0
# _________________________________________________________________
# conv2d_transpose_13 (Conv2DT (None, 60, 60, 32)        18432
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 60, 60, 32)        128
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 120, 120, 32)      0
# _________________________________________________________________
# activation_23 (Activation)   (None, 120, 120, 32)      0
# _________________________________________________________________
# conv2d_transpose_14 (Conv2DT (None, 120, 120, 1)       289
# =================================================================
# Total params: 1,368,385
# Trainable params: 1,366,465
# Non-trainable params: 1,920
# _________________________________________________________________
#
#
# ENTER AUGMENTATION SIZE: 10000
# ENTER BATCH SIZE: 100
# ENTER EPOCHS: 500
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# GENERATING DATA...
# DONE AUGMENTING...
#
# Epoch 1/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.8812 - accuracy: 0.5650 - mean_squared_error: 0.1722 - val_loss: 0.7642 - val_accuracy: 0.7662 - val_mean_squared_error: 0.0749
# Epoch 2/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.5694 - accuracy: 0.8065 - mean_squared_error: 0.0397 - val_loss: 0.5966 - val_accuracy: 0.7686 - val_mean_squared_error: 0.0562
# Epoch 3/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.5084 - accuracy: 0.8088 - mean_squared_error: 0.0270 - val_loss: 0.6007 - val_accuracy: 0.7608 - val_mean_squared_error: 0.0583
# Epoch 4/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.4739 - accuracy: 0.8091 - mean_squared_error: 0.0195 - val_loss: 0.5998 - val_accuracy: 0.7620 - val_mean_squared_error: 0.0578
# Epoch 5/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.4518 - accuracy: 0.8122 - mean_squared_error: 0.0158 - val_loss: 0.5996 - val_accuracy: 0.7611 - val_mean_squared_error: 0.0585
# Epoch 6/500
# 2/3 [===================>..........] - ETA: 0s - loss: 0.4424 - accuracy: 0.8075 - mean_squared_error: 0.0137
